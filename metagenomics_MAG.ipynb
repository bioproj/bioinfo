# %% [markdown]
# <a href="https://colab.research.google.com/github/bioproj/bioinfo/blob/master/metagenomics_MAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas openpyxl

# %%
# !wget https://ars.els-cdn.com/content/image/1-s2.0-S2666979X24001253-mmc10.xlsx
# Out:
# --2025-02-21 14:59:27--  https://ars.els-cdn.com/content/image/1-s2.0-S2666979X24001253-mmc10.xlsx
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 104.18.32.42, 172.64.155.214, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|104.18.32.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 118344 (116K) [application/excel]
# Saving to: ‘1-s2.0-S2666979X24001253-mmc10.xlsx.1’
#
# 1-s2.0-S2666979X240 100%[===================>] 115.57K  --.-KB/s    in 0.01s
#
# 2025-02-21 14:59:27 (8.41 MB/s) - ‘1-s2.0-S2666979X24001253-mmc10.xlsx.1’ saved [118344/118344]

# %%
import pandas as pd

# 读取 Excel 文件
df = pd.read_excel("1-s2.0-S2666979X24001253-mmc10.xlsx", header=1)

# %%
df
# Out:
#              isolates_id                   Marker lineage  Completeness  \
# 0            isolate_156      o__Lactobacillales (UID355)         99.18
# 1           isolate_1610      o__Lactobacillales (UID355)         99.18
# 2             isolate_17        g__Lactobacillus (UID436)         99.46
# 3             isolate_51      o__Lactobacillales (UID355)         99.45
# 4             isolate_63      o__Lactobacillales (UID355)         99.18
# ...                  ...                              ...           ...
# 1371     isolate_ZJHZ3M2  f__Bifidobacteriaceae (UID1462)        100.00
# 1372     isolate_ZJHZ7M2  f__Bifidobacteriaceae (UID1462)        100.00
# 1373   isolate_ZJHZD11M8  f__Bifidobacteriaceae (UID1458)        100.00
# 1374  isolate_ZJHZD20M12  f__Bifidobacteriaceae (UID1462)        100.00
# 1375   isolate_ZJHZD20M6  f__Bifidobacteriaceae (UID1460)        100.00
#
#       Contamination  Strain heterogeneity                              MAG_id  \
# ...
